# %%
import module1

a = module1.showName("sakda")
b = module1.plus(2)
# dir(module1)
print(a, b)
# Out:
# hello sakda 3

# %%
import module1 as md

b = md.plus(2)
print(b)
# Out:
# 3

# %%
from module1 import multiply as mul

c = mul(3)
print(c)
# Out:
# 6

# %%
import math

# dir(math)
a = math.sqrt(100)

print(a)
# Out:
# 10.0

# %%
import random as rd

# dir(rd)
# print(rd.random())
print(rd.randrange(10,20))
# Out:
# 13

# %%
import requests

res = requests.get("https://www.cmuccdc.org/api/ccdc/stations")

print(res.json())
# print(res.json()["message"])
# Out:
# [{'dustboy_id': '6388', 'dustboy_uri': 'tplus288', 'dustboy_alias': 'TPlus288', 'dustboy_name_th': 'รพ.สต.ต้นธง', 'dustboy_name_en': 'Tambon Tonthong Health Promoting Hospital, Lamphun', 'dustboy_lat': '18.555894', 'dustboy_lng': '98.980949', 'dustboy_status': '1', 'dustboy_pv': '39', 'dustboy_version': 'mini', 'db_email': '', 'db_co': 'นายกฤษฎา คำมะยอม', 'db_mobile': '088-2517590', 'db_addr': '', 'db_status': '0', 'db_model': 'T-Plus'}, {'dustboy_id': '6389', 'dustboy_uri': 'tplus289', 'dustboy_alias': 'TPlus289', 'dustboy_name_th': 'รพ.สต.หนองช้างคืน', 'dustboy_name_en': 'Nongchangkhuen Health Promoting Hospital, Lamphun', 'dustboy_lat': '18.65506652', 'dustboy_lng': '99.01749785', 'dustboy_status': '1', 'dustboy_pv': '39', 'dustboy_version': 'mini', 'db_email': '', 'db_co': 'นางมณีรัตน์ กัณธิยะ', 'db_mobile': '084-1704047', 'db_addr': '', 'db_status': '0', 'db_model': 'T-Plus'}, {'dustboy_id': '6390', 'dustboy_uri': 'tplus290', 'dustboy_alias': 'TPlus290', 'dustboy_name_th': 'รพ.ส
# ...

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
