# %%
import math

sqrt25 = math.sqrt(25)
pow5 = math.pow(5, 2)
print(sqrt25)
print(pow5)
print(math.pi)

print(dir(math))
# Out:
# 5.0
# 25.0
# 3.141592653589793
# ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
from math import pi, pow

print(pi)
# Out:
# 3.141592653589793

# %%
from math import *
import numpy as np

arr = np.array([1,2,3,4,5])
print(pi)
print(arr, type(arr))
# Out:
# 3.141592653589793
# [1 2 3 4 5] <class 'numpy.ndarray'>

# %%
# import student as st
from student import person1 as p1, person3 as p2

std1 = p1
std2 = p2
print(std1['fname'], std2['fname'])
# Out:
# sakda ole

# %%
import s2
import band_math as bm

# calculate ndvi
ndvi = bm.cal_ndvi(s2.data["b4"], s2.data["b3"])

# calculate ndwi
ndwi = bm.cal_ndwi(s2.data["b4"], s2.data["b5"])


print('ndvi: ', ndvi)
print('ndwi: ', ndwi)
# Out:
# ndvi:  0.797979797979798
# ndwi:  0.11949685534591199
