# %%
# 1) Connect to PostGIS
from sqlalchemy import create_engine, text
from sqlalchemy.pool import NullPool

PG_USER = "sakdahomhuan"
PG_PASS = "1234"
PG_HOST = "localhost"
PG_PORT = 5432
PG_DB   = "geo377"

engine = create_engine(
    f"postgresql+psycopg2://{PG_USER}:{PG_PASS}@{PG_HOST}:{PG_PORT}/{PG_DB}",
    poolclass=NullPool, future=True
)

with engine.begin() as conn:
    version = conn.execute(text("SELECT postgis_full_version();")).scalar_one()
version
# Out:
# 'POSTGIS="3.6.0 0" [EXTENSION] PGSQL="140" GEOS="3.14.0-CAPI-1.20.4" PROJ="9.6.2 NETWORK_ENABLED=OFF URL_ENDPOINT=https://cdn.proj.org USER_WRITABLE_DIRECTORY=/Users/sakdahomhuan/Library/Application Support/proj DATABASE_PATH=/opt/homebrew/Cellar/proj/9.6.2/share/proj/proj.db" (compiled against PROJ 9.6.2) GDAL="GDAL 3.11.3 "Eganville", released 2025/07/12" LIBXML="2.13.8" LIBJSON="0.18" LIBPROTOBUF="1.5.2" WAGYU="0.5.0 (Internal)" TOPOLOGY RASTER'

# %%
# 2) Initialize schema
sql = open("postgis_setup.sql", "r", encoding="utf-8").read()
with engine.begin() as conn:
    conn.exec_driver_sql(sql)
print("PostGIS workshop schema initialized.")
# Out:
# PostGIS workshop schema initialized.

# %%
# 3) Checks counts and SRID
from pandas import DataFrame
from sqlalchemy import text
with engine.begin() as conn:
    rs = conn.execute(text("""

        SELECT 'hospital' AS tbl, COUNT(*) AS n, MIN(ST_SRID(geom)) AS srid FROM public.cm_hospital_4326

        UNION ALL

        SELECT 'districts' AS tbl, COUNT(*) AS n, MIN(ST_SRID(geom)) AS srid FROM workshop.districts;

    """))
    df = DataFrame(rs.fetchall(), columns=rs.keys())
df
# Out:
#          tbl   n  srid
# 0   hospital  59  4326
# 1  districts   1  4326

# %%
# 4) Loads data from PostGIS to GeoDataFrame
import geopandas as gpd
from shapely.geometry import Point

gpoi = gpd.read_postgis(
    "SELECT id, name, geom FROM public.cm_hospital_4326",
    engine, geom_col="geom"
)
display(gpoi.head())
# Out:
#    id                       name                       geom
# 0   1  โรงพยาบาลกรุงเทพเชียงใหม่  POINT (99.02642 18.78853)
# 1   2         โรงพยาบาลกองบิน 41  POINT (98.97138 18.77809)
# 2   3            โรงพยาบาลกาวิละ  POINT (99.01483 18.77794)
# 3   4        โรงพยาบาลค่ายกาวิละ  POINT (99.01488 18.77793)
# 4   5            โรงพยาบาลจอมทอง  POINT (98.67392 18.40632)

# %%
# 5) Spatial query: find POIs within districts
import pandas as pd
from sqlalchemy import text

q1 = text("""

SELECT p.id, p.name,

       ST_AsText(p.geom) AS wkt,

       ST_Within(p.geom, d.geom) AS inside_district

FROM public.cm_hospital_4326 p

JOIN workshop.districts d

  ON p.geom && d.geom AND ST_Intersects(p.geom, d.geom);

""")
with engine.begin() as conn:
    df = pd.DataFrame(conn.execute(q1).fetchall(), columns=["id","name","wkt","inside_district"])
df
# Out:
#    id                       name                                          wkt  \
# 0   6         โรงพยาบาลช้างเผือก  POINT(98.98704276000007 18.798882440000057)
# 1  10      โรงพยาบาลเชียงใหม่ราม  POINT(98.97775677000004 18.795082310000055)
# 2  18  โรงพยาบาลเด็กเชียงใหม่ราม  POINT(98.97761676000005 18.794845690000045)
# 3  23         โรงพยาบาลเทพปัญญา2   POINT(98.98704010000006 18.79892756000004)
#
#    inside_district
# 0             True
# 1             True
# 2             True
# 3             True

# %%
# 6) Spatial query: KNN (K-Nearest Neighbor) search จาก hospital แต่ละแห่ง หา hospital ที่ใกล้ที่สุด 1 แห่ง
q2 = text("""

SELECT p.id, p.name,

       f.id  AS nearest_id,

       ST_Distance(p.geom::geography, f.geom::geography) AS meters

FROM public.cm_hospital_4326 p

CROSS JOIN LATERAL (

  SELECT id, geom FROM public.cm_hospital_4326 f

  WHERE f.id <> p.id

  ORDER BY f.geom <-> p.geom

  LIMIT 1

) f;

""")

with engine.begin() as conn:

    knn = conn.execute(q2).fetchall()

knn[:59]
# Out:
# [(1, 'โรงพยาบาลกรุงเทพเชียงใหม่', 20, 819.33034467),
#  (2, 'โรงพยาบาลกองบิน 41', 49, 841.44439205),
#  (3, 'โรงพยาบาลกาวิละ', 4, 5.00198492),
#  (4, 'โรงพยาบาลค่ายกาวิละ', 3, 5.00198492),
#  (5, 'โรงพยาบาลจอมทอง', 16, 13768.62303711),
#  (6, 'โรงพยาบาลช้างเผือก', 23, 5.00218406),
#  (7, 'โรงพยาบาลเชียงดาว', 33, 23923.73529582),
#  (8, 'โรงพยาบาลเชียงใหม่ใกล้หมอ', 30, 1397.41083621),
#  (9, 'โรงพยาบาลเชียงใหม่เมดิคอลเซ็นเตอร์', 28, 951.58271981),
#  (10, 'โรงพยาบาลเชียงใหม่ราม', 18, 30.06398092),
#  (11, 'โรงพยาบาลเชียงใหม่ฮอสพิทอล', 42, 5.59247548),
#  (12, 'โรงพยาบาลไชยปราการ', 32, 24146.81153443),
#  (13, 'โรงพยาบาลเซ็นทรัลเชียงใหม่เมโมเรียล', 48, 396.81346642),
#  (14, 'โรงพยาบาลดอยเต่า', 59, 26715.20350147),
#  (15, 'โรงพยาบาลดอยสะเก็ด', 20, 13529.4947916),
#  (16, 'โรงพยาบาลดอยหล่อ', 5, 13768.62303711),
#  (17, 'โรงพยาบาลดารารัศมี', 52, 5078.49230622),
#  (18, 'โรงพยาบาลเด็กเชียงใหม่ราม', 10, 30.06398092),
#  (19, 'โรงพยาบาลตาเซนต์ปีเตอร์', 43, 142.42742105),
#  (20, 'โรงพยาบาลตำบลหนองป่าครั่ง', 1, 819.33034467),
#  (21, 'โรงพยาบาลทันตกรรมเอเซียฟอร์จูน', 58, 43.62554859),
#  (22, 'โรงพยาบาลเทพปัญญา', 35, 1331.68347452),
#  (23, 'โรงพยาบาลเทพปัญญา2', 6, 5.00218406),
#  (24, 'โรงพยาบาลเทพรัตนเวชชานุกูลเฉลิมพระเกียรติ 60 พรรษา', 5, 34161.42732598),
#  (25, 'โรงพยาบาลเทศบาลนครเชียงใหม่', 29, 893.76261328),
#  (26, 'โรงพยาบาลธัญญารักษ์เชียงใหม่', 17, 11799.87805386),
#  (27, 'โรงพยาบาลนครพิงค์', 42, 4755.76809982),
#  (28, 'โรงพยาบาลนครพิงค์ สาขาศรีดอนไชย', 29, 5.00240335),
#  (29, 'โรงพยาบาลนครพิงค์สาขาศรีดอนไชย', 28, 5.00240335),
#  (30, 'โรงพยาบาลบรรเทาทุกข์โบราณภาคเหนือชีวกโกมารภัจจ์', 49, 913.0797652),
#  (31, 'โรงพยาบาลประสาทเชียงใหม่', 34, 501.04709173),
#  (32, 'โรงพยาบาลฝาง', 40, 17115.47837161),
#  (33, 'โรงพยาบาลพร้าว', 7, 23923.73529582),
#  (34, 'โรงพยาบาลมหาราชนครเชียงใหม่', 31, 501.04709173),
#  (35, 'โรงพยาบาลแมคคอร์มิค', 22, 1331.68347452),
#  (36, 'โรงพยาบาลแมคเคน', 8, 3841.12324367),
#  (37, 'โรงพยาบาลแม่แตง', 26, 13506.21163812),
#  (38, 'โรงพยาบาลแม่วาง', 53, 11961.02154803),
#  (39, 'โรงพยาบาลแม่ออน', 51, 10900.87982795),
#  (40, 'โรงพยาบาลแม่อาย', 32, 17115.47837161),
#  (41, 'โรงพยาบาลราชเวช', 13, 924.01973697),
#  (42, 'โรงพยาบาลโรคฟัน', 11, 5.59247548),
#  (43, 'โรงพยาบาลลานนา', 44, 48.55509718),
#  (44, 'โรงพยาบาลลานนา 2', 43, 48.55509718),
#  (45, 'โรงพยาบาลวัดจันทร์เฉลิมพระเกียรติ', 46, 5.00134883),
#  (46, 'โรงพยาบาลวัดจันทร์เฉลิมพระเกียรติ 80 พรรษา', 45, 5.00134883),
#  (47, 'โรงพยาบาลเวียงแหง', 7, 39713.78609531),
#  (48, 'โรงพยาบาลส่งเสริมสุขภาพเชียงใหม่', 13, 396.81346642),
#  (49, 'โรงพยาบาลสวนปรุง', 2, 841.44439205),
#  (50, 'โรงพยาบาลสะเมิง', 17, 23491.05124354),
#  (51, 'โรงพยาบาลสันกำแพง', 55, 6530.40762696),
#  (52, 'โรงพยาบาลสันทราย', 17, 5078.49230622),
#  (53, 'โรงพยาบาลสันป่าตอง', 56, 10309.3618667),
#  (54, 'โรงพยาบาลสารภี', 55, 3551.76404436),
#  (55, 'โรงพยาบาลสารภีบวรพัฒนา', 54, 3551.76404436),
#  (56, 'โรงพยาบาลหางดง', 36, 8792.69210507),
#  (57, 'โรงพยาบาลอมก๋อย', 14, 38602.31098348),
#  (58, 'โรงพยาบาลเอ็มทีอินเตอร์เมด', 21, 43.62554859),
#  (59, 'โรงพยาบาลฮอด', 5, 25978.00560547)]

# %%
# 7) Spatial query: aggregate hospital counts by district
q3 = text("""

SELECT d.name, COUNT(p.*) AS cnt

FROM workshop.districts d

LEFT JOIN public.cm_hospital_4326 p

  ON d.geom && p.geom AND ST_Intersects(d.geom, p.geom)

GROUP BY d.name ORDER BY cnt DESC;

""")

import pandas as pd

with engine.begin() as conn:

    agg = pd.DataFrame(conn.execute(q3).fetchall(), columns=["district","count"])

agg
# Out:
#         district  count
# 0  Demo District      4

# %%
# 8) Export query result as GeoJSON
from sqlalchemy import text
q_geojson = text("""

SELECT jsonb_build_object(

  'type','FeatureCollection',

  'features', jsonb_agg(jsonb_build_object(

     'type','Feature',

     'properties', jsonb_build_object('id', id, 'name', name),

     'geometry', ST_AsGeoJSON(geom)::jsonb

  ))

) AS fc

FROM public.cm_hospital_4326;

""")

with engine.begin() as conn:

    fc = conn.execute(q_geojson).scalar_one()

fc
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.02642032, 18.78853112]},
#    'properties': {'id': 1, 'name': 'โรงพยาบาลกรุงเทพเชียงใหม่'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97138436, 18.77808769]},
#    'properties': {'id': 2, 'name': 'โรงพยาบาลกองบิน 41'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.01483439, 18.77794254]},
#    'properties': {'id': 3, 'name': 'โรงพยาบาลกาวิละ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.01487874, 18.77792649]},
#    'properties': {'id': 4, 'name': 'โรงพยาบาลค่ายกาวิละ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.67391898, 18.40632131]},
#    'properties': {'id': 5, 'name': 'โรงพยาบาลจอมทอง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.98704276, 18.79888244]},
#    'properties': {'id': 6, 'name': 'โรงพยาบาลช้างเผือก'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97516318, 19.40295128]},
#    'properties': {'id': 7, 'name': 'โรงพยาบาลเชียงดาว'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97234376, 18.76062113]},
#    'properties': {'id': 8, 'name': 'โรงพยาบาลเชียงใหม่ใกล้หมอ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.9884352, 18.78018104]},
#    'properties': {'id': 9, 'name': 'โรงพยาบาลเชียงใหม่เมดิคอลเซ็นเตอร์'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97775677, 18.79508231]},
#    'properties': {'id': 10, 'name': 'โรงพยาบาลเชียงใหม่ราม'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.98150745, 18.81067293]},
#    'properties': {'id': 11, 'name': 'โรงพยาบาลเชียงใหม่ฮอสพิทอล'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.13685897, 19.70564367]},
#    'properties': {'id': 12, 'name': 'โรงพยาบาลไชยปราการ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99832212, 18.77312065]},
#    'properties': {'id': 13, 'name': 'โรงพยาบาลเซ็นทรัลเชียงใหม่เมโมเรียล'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.69090941, 17.95016802]},
#    'properties': {'id': 14, 'name': 'โรงพยาบาลดอยเต่า'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.12840019, 18.86899463]},
#    'properties': {'id': 15, 'name': 'โรงพยาบาลดอยสะเก็ด'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.78056305, 18.47783746]},
#    'properties': {'id': 16, 'name': 'โรงพยาบาลดอยหล่อ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.9450781, 18.91060335]},
#    'properties': {'id': 17, 'name': 'โรงพยาบาลดารารัศมี'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97761676, 18.79484569]},
#    'properties': {'id': 18, 'name': 'โรงพยาบาลเด็กเชียงใหม่ราม'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99085585, 18.81138711]},
#    'properties': {'id': 19, 'name': 'โรงพยาบาลตาเซนต์ปีเตอร์'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.03384176, 18.78633402]},
#    'properties': {'id': 20, 'name': 'โรงพยาบาลตำบลหนองป่าครั่ง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.02482468, 18.79704572]},
#    'properties': {'id': 21, 'name': 'โรงพยาบาลทันตกรรมเอเซียฟอร์จูน'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.01147561, 18.81024424]},
#    'properties': {'id': 22, 'name': 'โรงพยาบาลเทพปัญญา'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.9870401, 18.79892756]},
#    'properties': {'id': 23, 'name': 'โรงพยาบาลเทพปัญญา2'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.36515554, 18.49812409]},
#    'properties': {'id': 24,
#     'name': 'โรงพยาบาลเทพรัตนเวชชานุกูลเฉลิมพระเกียรติ 60 พรรษา'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.00176634, 18.78848259]},
#    'properties': {'id': 25, 'name': 'โรงพยาบาลเทศบาลนครเชียงใหม่'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.94041608, 19.01711238]},
#    'properties': {'id': 26, 'name': 'โรงพยาบาลธัญญารักษ์เชียงใหม่'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.9680547, 18.85173638]},
#    'properties': {'id': 27, 'name': 'โรงพยาบาลนครพิงค์'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99734605, 18.78154876]},
#    'properties': {'id': 28, 'name': 'โรงพยาบาลนครพิงค์ สาขาศรีดอนไชย'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99734375, 18.7815939]},
#    'properties': {'id': 29, 'name': 'โรงพยาบาลนครพิงค์สาขาศรีดอนไชย'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97822769, 18.7719334]},
#    'properties': {'id': 30,
#     'name': 'โรงพยาบาลบรรเทาทุกข์โบราณภาคเหนือชีวกโกมารภัจจ์'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.96957309, 18.78972775]},
#    'properties': {'id': 31, 'name': 'โรงพยาบาลประสาทเชียงใหม่'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.2063716, 19.91361029]},
#    'properties': {'id': 32, 'name': 'โรงพยาบาลฝาง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.19989884, 19.36794696]},
#    'properties': {'id': 33, 'name': 'โรงพยาบาลพร้าว'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97432122, 18.78952924]},
#    'properties': {'id': 34, 'name': 'โรงพยาบาลมหาราชนครเชียงใหม่'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.01082765, 18.7982293]},
#    'properties': {'id': 35, 'name': 'โรงพยาบาลแมคคอร์มิค'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.98660615, 18.72868991]},
#    'properties': {'id': 36, 'name': 'โรงพยาบาลแมคเคน'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.96017762, 19.13767216]},
#    'properties': {'id': 37, 'name': 'โรงพยาบาลแม่แตง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.77411726, 18.61586806]},
#    'properties': {'id': 38, 'name': 'โรงพยาบาลแม่วาง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.221643, 18.74459224]},
#    'properties': {'id': 39, 'name': 'โรงพยาบาลแม่ออน'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.30241634, 20.03874092]},
#    'properties': {'id': 40, 'name': 'โรงพยาบาลแม่อาย'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.00417984, 18.76691148]},
#    'properties': {'id': 41, 'name': 'โรงพยาบาลราชเวช'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.98149662, 18.81072239]},
#    'properties': {'id': 42, 'name': 'โรงพยาบาลโรคฟัน'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99130361, 18.81260113]},
#    'properties': {'id': 43, 'name': 'โรงพยาบาลลานนา'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99127799, 18.81303911]},
#    'properties': {'id': 44, 'name': 'โรงพยาบาลลานนา 2'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.31533968, 19.07743794]},
#    'properties': {'id': 45, 'name': 'โรงพยาบาลวัดจันทร์เฉลิมพระเกียรติ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.31531486, 19.07747647]},
#    'properties': {'id': 46,
#     'name': 'โรงพยาบาลวัดจันทร์เฉลิมพระเกียรติ 80 พรรษา'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.63515752, 19.56020025]},
#    'properties': {'id': 47, 'name': 'โรงพยาบาลเวียงแหง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99456402, 18.77331484]},
#    'properties': {'id': 48, 'name': 'โรงพยาบาลส่งเสริมสุขภาพเชียงใหม่'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.97906803, 18.7801435]},
#    'properties': {'id': 49, 'name': 'โรงพยาบาลสวนปรุง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.73245, 18.84679812]},
#    'properties': {'id': 50, 'name': 'โรงพยาบาลสะเมิง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.12276508, 18.71589218]},
#    'properties': {'id': 51, 'name': 'โรงพยาบาลสันกำแพง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.99222051, 18.9201971]},
#    'properties': {'id': 52, 'name': 'โรงพยาบาลสันทราย'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.88542152, 18.59550692]},
#    'properties': {'id': 53, 'name': 'โรงพยาบาลสันป่าตอง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.0431462, 18.68094114]},
#    'properties': {'id': 54, 'name': 'โรงพยาบาลสารภี'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.06142088, 18.70789195]},
#    'properties': {'id': 55, 'name': 'โรงพยาบาลสารภีบวรพัฒนา'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.91824127, 18.68323404]},
#    'properties': {'id': 56, 'name': 'โรงพยาบาลหางดง'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.36116949, 17.80199232]},
#    'properties': {'id': 57, 'name': 'โรงพยาบาลอมก๋อย'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [99.02502118, 18.79739258]},
#    'properties': {'id': 58, 'name': 'โรงพยาบาลเอ็มทีอินเตอร์เมด'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [98.61156999, 18.17929884]},
#    'properties': {'id': 59, 'name': 'โรงพยาบาลฮอด'}}]}

# %%
# show with folium
import folium
m = folium.Map(location=[18.79, 98.98], zoom_start=12)
# folium.GeoJson(fc, name="geojson").add_to(m)
# add marker popup 
for feature in fc['features']:
    coords = feature['geometry']['coordinates'][::-1]  # reverse to (lat, lon)
    name = feature['properties']['name']
    folium.Marker(location=coords, popup=name).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db32c5bcf475fa0f550caf0267624eb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db32c5bcf475fa0f550caf0267624eb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db32c5bcf475fa0f550caf0267624eb1 = L.map(
#                 &quot;map_db32c5bcf475fa0f550caf0267624eb1&quot;,
#                 {
#                     center: [18.79, 98.98],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbeecba89e42ae62bd8766761d367bac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fbeecba89e42ae62bd8766761d367bac.addTo(map_db32c5bcf475fa0f550caf0267624eb1);
#
#
#             var marker_ef870a4d52de9f6a2dc43c977cc2cc93 = L.marker(
#                 [18.78853112, 99.02642032],
#                 {
# }
#             ).addTo(map_db32c5bcf475fa0f550caf0267624eb1);
#
#
#         var popup_d484b5c90cbc9dc02c49435247d0a318 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_431d39dd0a53b002308c4700695e30fc = $(`&lt;div id=&quot;html_431d39dd0a53b002308c4700695e30fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;โรงพยาบาลกรุงเทพเชียงใหม่&lt;/div&gt;`)[0];
#                 popup_d484b5c90cbc9dc02c49435247d0a318.setContent(html_431d39dd0a53b002308c4700695e30fc);
#
#
#
#         marker_ef870a4d52de9f6a2dc43c977cc2cc93.bindPopup(popup_d484b5c90cbc9dc02c49435247d0a318)
#         ;
#
#
#
#
#             var marker_59d7c13e5837232b269ed16461ee7bd6 = L.marker(
#                 [18.77808769, 98.97138436],
#                 {
# }
#             ).addTo(map_db32c5bcf475fa0f550caf0267624eb1);
#
#
#         var popup_edc3242da1ec73121e02483df1bf46ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_283cd1ec7da0490d4b0141ade7e51e27 = $(`&lt;div id=&quot;html_283cd1ec7da0490d4b0141ade7e51e27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;โรงพยาบาลกองบิน 41&lt;/div&gt;`)[0];
#                 popup_edc3242da1ec73121e02483df1bf46ac.setContent(html_283cd1ec7da0490d4b0141ade7e51e27);
#
#
#
#         marker_59d7c13e5837232b269ed16461ee7bd6.bindPopup(popup_edc3242da1ec73121e02483df1bf46ac)
#         ;
#
#
#
#
#             var marker_0be56ed209fed574f1696e0d443eb648 = L.marker(
#                 [18.77794254, 99.01483439],
#                 {
# }
#             ).addTo(map_db32c5bcf475fa0f550caf0267624eb1);
#
#
#         var popup_e66549c5f4294979d7223c3b84b37a69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bbb811a9e120cfd9230482917a38642 = $(`&lt;div id=&quot;html_4bbb811a9e120cfd9230482917a38642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;โรงพยาบาลกาวิละ&lt;/div&gt;`)[0];
#                 popup_e66549c5f4294979d7223c3b84b37a69.setContent(html_4bbb811a9e120cfd9230482917a38642);
#
#
#
#         marker_0be56ed209fed574f1696e0d443eb648.bindPopup(popup_e66549c5f4294979d7223c3b84b37a69)
#         ;
#
#
#
#
#             var marker_0ccc5ec29182ffc67b8ca238b4c1aada = L.marker(
#                 [18.77792649, 99.01487874],
#                 {
# }
#             ).addTo(map_db32c5bcf475fa0f550caf0267624eb1);
#
#
#         var popup_42591847384ee2f32649646b37cafdf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_858f81b40f7e0bb3250439fe8bc08377 = $(`&lt;div id=&quot;html_858f81b40f7e0bb3250439fe8bc08377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;โรงพยาบาลค่ายกาวิละ&lt;/div&gt;`)[0];
#                 popup_42591847384ee2f32649646b37cafdf3.setContent(html_858f81b40f7e0bb3250439fe8bc08377);
#
#
#
#         marker_0ccc5ec29182ffc67b8ca238b4c1aada.bindPopup(popup_42591847384ee2f32649646b37cafdf3)
#         ;
#
#
#
#
#             var marker_8ffff30d4dd3ca4d776a9ba738ce269f = L.marker(
#                 [18.40632131, 98.67391898],
#                 {
# }
#             ).addTo(map_db32c5bcf475fa0f550caf0267624eb1);
#
#
#         var popup_29bdc732deeeb021cc94b2bba7b9516e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0a9c53dacd9d75df7fbf40e2ee21438 = $(`&lt;div id=&quot;html_c0a9c53dacd9d75df7fbf40e2ee21438&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;โรงพยาบาลจอมทอง&lt;/div&gt;`)[0];
#                 popup_29bdc732deeeb021cc94b2bba7b9516e.setContent(html_c0a9c53dacd9d75df7fbf40e2ee21438);
